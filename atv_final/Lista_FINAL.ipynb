# %% [markdown]
# <a href="https://colab.research.google.com/github/agiribeiro/EDB-Python/blob/master/Lista/Lista_FINAL.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #TRABALHO FINAL

# %% [markdown]
# #Questão 1:
#
# Desenvolva um jogo da forca. O programa terá uma lista de palavras lidas de uma lista e escolherá uma palavra aleatoriamente. O jogador vai tentar descobrir essa palavra, mas só poderá errar 6 vezes antes de ser enforcado.
#
# Digite uma letra: A
# -> Você errou pela 1ª vez. Tente de novo!
#
# Digite uma letra: O
# A palavra é: _ _ _ _ O
#
# Digite uma letra: E
# A palavra é: _ E _ _ O
#
# Digite uma letra: S
# -> Você errou pela 2ª vez. Tente de novo!
#
# Quando errar pela 6ª vez imprimir: Enforcado e exibir a palavra correta

# %%
import random

def jogar_forca():

    palavras = [ "COMPUTADOR", "ABACAXI", "ESQUILO", "GIRASSOL", "CHOCOLATE", "MELANCIA", "JACARÉ", "AVIÃO", "TIGELA", "ELEFANTE", "BANANA", "SORVETE", "PIPOCA", "LARANJA", "GUITARRA", "CACHORRO", "FUTEBOL", "PIANO", "BICICLETA", "GIRAFA" ]
    palavra = random.choice(palavras)
    letras_acertadas = ['_'] * len(palavra)
    tentativas = 0
    letras_erradas = []

    print("Bem-vindo ao jogo da forca!")
    print("Adivinhe a palavra secreta.")
    print_mostra_forca(tentativas)

    while True:
        letra = input("\nDigite uma letra: ").strip().upper()

        if letra in letras_erradas or letra in letras_acertadas:
            print("Essa letra já foi tentada. Tente outra vez!")
            continue

        if letra in palavra:
            for i in range(len(palavra)):
                if palavra[i] == letra:
                    letras_acertadas[i] = letra
            print("\nA palavra é: " + ' '.join(letras_acertadas))

            if '_' not in letras_acertadas:
                print("Parabéns! Você acertou a palavra!")
                break
        else:
            tentativas += 1
            letras_erradas.append(letra)
            print("\nVocê errou pela", tentativas, "ª vez. Tente de novo!")
            print_mostra_forca(tentativas)

            if tentativas == 6:
                print("Enforcado! A palavra correta era:", palavra)
                break

def print_mostra_forca(tentativas):
    forca = [
        '''
        +---+
        |   |
            |
            |
            |
            |
      =======''',
        '''
        +---+
        |   |
        O   |
            |
            |
            |
      =======''',
        '''
        +---+
        |   |
        O   |
        |   |
            |
            |
      =======''',
        '''
        +---+
        |   |
        O   |
       /|   |
            |
            |
      =======''',
        '''
        +---+
        |   |
        O   |
       /|\\  |
            |
            |
      =======''',
        '''
        +---+
        |   |
        O   |
       /|\\  |
       /    |
            |
      =======''',
        '''
        +---+
        |   |
        O   |
       /|\\  |
       / \\  |
            |
      ======='''
    ]
    print(forca[tentativas])

jogar_forca()
# Out:
# Bem-vindo ao jogo da forca!
# Adivinhe a palavra secreta.
#
#         +---+
#         |   |
#             |
#             |
#             |
#             |
#       =======
#
# Digite uma letra: a
#
# Você errou pela 1 ª vez. Tente de novo!
#
#         +---+
#         |   |
#         O   |
#             |
#             |
#             |
#       =======
#
# Digite uma letra: e
#
# A palavra é: E _ _ _ _ _ _
#
# Digite uma letra: s
#
# A palavra é: E S _ _ _ _ _
#
# Digite uma letra: t
#
# Você errou pela 2 ª vez. Tente de novo!
#
#         +---+
#         |   |
#         O   |
#         |   |
#             |
#             |
#       =======
#
# Digite uma letra: o
#
# A palavra é: E S _ _ _ _ O
#
# Digite uma letra: u
#
# A palavra é: E S _ U _ _ O
#
# Digite uma letra: r
#
# Você errou pela 3 ª vez. Tente de novo!
#
#         +---+
#         |   |
#         O   |
#        /|   |
#             |
#             |
#       =======
#
# Digite uma letra: n
#
# Você errou pela 4 ª vez. Tente de novo!
#
#         +---+
#         |   |
#         O   |
#        /|\  |
#             |
#             |
#       =======
#
# Digite uma letra: l
#
# A palavra é: E S _ U _ L O
#
# Digite uma letra: p
#
# Você errou pela 5 ª vez. Tente de novo!
#
#         +---+
#         |   |
#         O   |
#        /|\  |
#        /    |
#             |
#       =======
#
# Digite uma letra: m
#
# Você errou pela 6 ª vez. Tente de novo!
#
#         +---+
#         |   |
#         O   |
#        /|\  |
#        / \  |
#             |
#       =======
# Enforcado! A palavra correta era: ESQUILO

# %% [markdown]
# #Questão 3
#
# Criei um simulador de jogo de poker. Considere que o baralho tem cartas : 2,3,4,5,6,7,8,9,10, Valete, Dama, Rei e Às.
# Nessa simulação você terá dois jogadores.
#
# **Primeiro passo: Atribua uma mão contendo 5 cartas, geradas de forma aleatória, para cada jogador. Cada carta tem um VALOR e um NAIPE**
#
# **Segundo passo: Compare os jogos dos dois jogadores e diga qual o nome do jogo que cada um tem na sua mão, mostre as mãos dos dois, e diga quem foi o vencedor.**
#
# POSSIBILIDADES DE MÃOS:
#
# **Classificação de Mãos de Poker Tradicional **
#
# **Straight Flush: Cinco cartas em ordem numérica, todas do mesmo naipe.**
#
# No caso de um empate: A carta de maior valor no topo da sequência vence.
#
# O melhor Straight Flush possível é conhecido como Royal Flush, que consiste na sequência de Ás, Rei, Dama, Valete e Dez do mesmo naipe. O Royal Flush é uma mão imbatível.
#
# **Quadra:
# Quatro cartas de mesmo valor, e uma outra carta como 'Kicker'.**
#
# Quadra
# No caso de um empate: A maior quadra vence. Em jogos com cartas comunitárias onde os jogadores podem conseguir a mesma quadra, a maior quinta carta (Kicker) vence.
#
# **Full House: Três cartas do mesmo valor, e duas outras cartas diferentes de mesmo valor.**
#
# Full House
# No caso de um empate: As maiores três cartas do mesmo valor vencem o pote. Em jogos com cartas comunitárias onde os jogadores podem conseguir as mesmas três cartas de valor igual, vence aquele com o par de maior valor.
#
# **Flush: Cinco cartas do mesmo naipe.**
#
# Flush
# No caso de um empate: O jogador com a carta de maior valor vence. Se necessário, a segunda carta, a terceira carta, a quarta carta e a quinta carta podem ser utilizadas para desempate. Se as cinco cartas forem do mesmo valor, o pote é dividido. O naipe nunca é utilizado como critério de desempate no poker.
#
# **Sequência: Cinco cartas em sequência.**
#
# Sequência
# No caso de um empate: A carta de maior valor no topo da sequência vence.
#
# Observação: O Ás pode ser utilizado no topo ou na parte baixa da sequência, e é a única carta que pode ser utilizada dessa forma. A,K,Q,J,T é a maior sequência (Ás alto ou Ace High); 5,4,3,2,A é a menor sequência (5 alto ou Five High).
#
# **Trinca: Três cartas do mesmo valor, e duas outras cartas não relacionadas.**
#
# Trinca
# No caso de um empate: A trinca de maior valor vence. Em jogos com cartas comunitárias onde os jogadores podem ter a mesma trinca, ganha o jogador com a maior carta além das três de mesmo valor, e se necessário a segunda maior carta será utilizada para desempate.
#
# **Dois pares: Duas cartas de um mesmo valor, outras duas cartas diferentes de mesmo valor, e uma outra carta não relacionada**
#
# Dois Pares
# No caso de um empate: O par maior vence. Se os jogadores possuírem o mesmo par mais alto, o segundo par decide o vencedor. Se os dois jogadores tiverem pares idênticos, a quinta carta define o vencedor.
#
# **Um Par: Duas cartas do mesmo valor, e três outras cartas não relacionadas.**
#
# Um Par
# No caso de um empate: O par maior vence. Se dois jogadores tiverem o mesmo par, a maior carta fora do par define o vencedor, e se necessário a segunda maior carta e a terceira maior carta pode ser utilizadas para o desempate.
#
# **Carta Alta: Qualquer mão que não esteja nas categorias acima.**
#
# Carta Alta
# No caso de um empate: A maior carta vence, e se necessário, a segunda carta, a terceira carta, a quarta carta e a quinta carta podem ser utilizadas para desempate.
#
# Mais informações: https://www.pokerstars.com/br/poker/games/rules/hand-rankings/?no_redirect=1

# %%
import random

valores = ['2', '3', '4', '5', '6', '7', '8', '9', '10', 'Valete', 'Dama', 'Rei', 'Ás']
naipes = ['Copas', 'Espadas', 'Ouros', 'Paus']

def gerar_mao():
    return random.sample(valores, 5), random.choice(naipes)


def verificar_mao(mao):
    valores_mao, naipe_mao = mao
    valores_mao.sort(key=lambda x: valores.index(x))
    is_flush = len(set(naipe_mao)) == 1
    is_straight = "".join(valores_mao) in "".join(valores)

    if is_flush and is_straight:
        if valores_mao[-1] == 'Ás' and valores_mao[0] == '10':
            return "Royal Flush", valores_mao
        else:
            return "Straight Flush", valores_mao
    elif valores_mao.count(valores_mao[2]) == 4:
        return "Quadra", valores_mao
    elif valores_mao.count(valores_mao[1]) == 3 and valores_mao.count(valores_mao[3]) == 2:
        return "Full House", valores_mao
    elif is_flush:
        return "Flush", valores_mao
    elif is_straight:
        return "Sequência", valores_mao
    elif valores_mao.count(valores_mao[2]) == 3:
        return "Trinca", valores_mao
    elif valores_mao.count(valores_mao[1]) == 2 and valores_mao.count(valores_mao[3]) == 2:
        return "Dois Pares", valores_mao
    elif valores_mao.count(valores_mao[1]) == 2:
        return "Um Par", valores_mao
    else:
        return "Carta Alta", valores_mao

def determinar_vencedor(mao_jogador1, mao_jogador2):
    categoria_jogador1, valores_jogador1 = mao_jogador1
    categoria_jogador2, valores_jogador2 = mao_jogador2

    if categorias.index(categoria_jogador1) > categorias.index(categoria_jogador2):
        return "Jogador 1"
    elif categorias.index(categoria_jogador1) < categorias.index(categoria_jogador2):
        return "Jogador 2"
    else:
        for valor1, valor2 in zip(valores_jogador1[::-1], valores_jogador2[::-1]):
            if valores.index(valor1) > valores.index(valor2):
                return "Jogador 1"
            elif valores.index(valor1) < valores.index(valor2):
                return "Jogador 2"
        return "Empate"


categorias = ["Carta Alta", "Um Par", "Dois Pares", "Trinca", "Sequência", "Flush", "Full House", "Quadra", "Straight Flush", "Royal Flush"]
for _ in range(100):
    mao_jogador1 = gerar_mao()
    mao_jogador2 = gerar_mao()

    print("Mão do Jogador 1:", mao_jogador1)
    print("Jogo do Jogador 1:", verificar_mao(mao_jogador1)[0])
    print("Mão do Jogador 2:", mao_jogador2)
    print("Jogo do Jogador 2:", verificar_mao(mao_jogador2)[0])

    vencedor = determinar_vencedor(verificar_mao(mao_jogador1), verificar_mao(mao_jogador2))
    print("Vencedor:", vencedor)
    print()
# Out:
# Mão do Jogador 1: (['10', '3', '9', '7', '5'], 'Ouros')
# Jogo do Jogador 1: Carta Alta
# Mão do Jogador 2: (['6', '5', '3', 'Rei', '8'], 'Espadas')
# Jogo do Jogador 2: Carta Alta
# Vencedor: Jogador 2
#
# Mão do Jogador 1: (['4', '3', '7', 'Valete', '2'], 'Espadas')
# Jogo do Jogador 1: Carta Alta
# Mão do Jogador 2: (['6', 'Rei', '7', 'Ás', '4'], 'Ouros')
# Jogo do Jogador 2: Carta Alta
# Vencedor: Jogador 2
#
# Mão do Jogador 1: (['5', '10', '6', '2', '8'], 'Copas')
# Jogo do Jogador 1: Carta Alta
# Mão do Jogador 2: (['Valete', '4', '10', '2', 'Dama'], 'Espadas')
# Jogo do Jogador 2: Carta Alta
# Vencedor: Jogador 2
#
# Mão do Jogador 1: (['2', '3', '4', '10', 'Dama'], 'Espadas')
# Jogo do Jogador 1: Carta Alta
# Mão do Jogador 2: (['10', 'Valete', '6', 'Rei', '8'], 'Copas')
# Jogo do Jogador 2: Carta Alta
# Vencedor: Jogador 2
#
# Mão do Jogador 1: (['9', '3', '8', 'Rei', '4'], 'Ouros')
# Jogo do Jogador 1: Carta Alta
# Mão do Jogador 2: (['9', 'Valete', 'Ás', '2', '8'], 'Paus')
# Jogo do Jogador 2: Carta Alta
# Vencedor: Jogador 2
#
# Mão do Jogador 1: (['5', '10', 'Valete', '8', 'Ás'], 'Copas')
# Jogo do Jogador 1: Carta Alta
# Mão do Jogador 2: (['3', '10', 'Dama', '6', 'Ás'], 'Copas')
# Jogo do Jogador 2: Carta Alta
# Vencedor: Jogador 2
#
# Mão do Jogador 1: (['Rei', '6', '9', '4', 'Valete'], 'Ouros')
# Jogo do Jogador 1: Carta Alta
# Mão do Jogador 2: (['7', '8', 'Rei', '3', '2'], 'Espadas')
# Jogo do Jogador 2: Carta Alta
# Vencedor: Jogador 1
#
# Mão do Jogador 1: (['8', 'Dama', '5', 'Ás', '6'], 'Espadas')
# Jogo do Jogador 1: Carta Alta
# Mão do Jogador 2: (['Rei', '9', '6', '5', '7'], 'Paus')
# Jogo do Jogador 2: Carta Alta
# Vencedor: Jogador 1
#
# Mão do Jogador 1: (['Rei', '9', '8', 'Valete', '4'], 'Paus')
# Jogo do Jogador 1: Carta Alta
# Mão do Jogador 2: (['Ás', '9', '2', '6', '8'], 'Paus')
# Jogo do Jogador 2: Carta Alta
# Vencedor: Jogador 2
#
# Mão do Jogador 1: (['Rei', 'Ás', '6', 'Valete', '9'], 'Ouros')
# Jogo do Jogador 1: Carta Alta
# Mão do Jogador 2: (['10', '2', 'Rei', '9', '3'], 'Copas')
# Jogo do Jogador 2: Carta Alta
# Vencedor: Jogador 1
#
# Mão do Jogador 1: (['9', '3', 'Valete', 'Rei', '8'], 'Copas')
# Jogo do Jogador 1: Carta Alta
# Mão do Jogador 2: (['10', '7', '9', '8', '2'], 'Espadas')
# Jogo do Jogador 2: Carta Alta
# Vencedor: Jogador 1
#
# Mão do Jogador 1: (['5', '7', '10', '6', '2'], 'Espadas')
# Jogo do Jogador 1: Carta Alta
# Mão do Jogador 2: (['6', 'Valete', '5', 'Rei', '2'], 'Paus')
# Jogo do Jogador 2: Carta Alta
# Vencedor: Jogador 2
#
# Mão do Jogador 1: (['Dama', '8', '4', 'Rei', 'Ás'], 'Paus')
# Jogo do Jogador 1: Carta Alta
# Mão do Jogador 2: (['2', 'Dama', '6', '10', '3'], 'Copas')
# Jogo do Jogador 2: Carta Alta
# Vencedor: Jogador 1
#
# Mão do Jogador 1: (['9', '10', 'Ás', '8', '7'], 'Copas')
# Jogo do Jogador 1: Carta Alta
# Mão do Jogador 2: (['3', 'Ás', '2', '5', 'Rei'], 'Espadas')
# Jogo do Jogador 2: Carta Alta
# Vencedor: Jogador 2
#
# Mão do Jogador 1: (['2', '4', '7', '8', 'Valete'], 'Copas')
# Jogo do Jogador 1: Carta Alta
# Mão do Jogador 2: (['8', 'Rei', '10', '7', '4'], 'Ouros')
# Jogo do Jogador 2: Carta Alta
# Vencedor: Jogador 2
#
# Mão do Jogador 1: (['5', 'Valete', '4', '10', '6'], 'Ouros')
# Jogo do Jogador 1: Carta Alta
# Mão do Jogador 2: (['9', 'Dama', '4', '2', 'Valete'], 'Paus')
# Jogo do Jogador 2: Carta Alta
# Vencedor: Jogador 2
#
# Mão do Jogador 1: (['8', '3', 'Dama', 'Rei', '10'], 'Ouros')
# Jogo do Jogador 1: Carta Alta
# Mão do Jogador 2: (['10', 'Valete', '7', 'Rei', '8'], 'Copas')
# Jogo do Jogador 2: Carta Alta
# Vencedor: Jogador 1
#
# Mão do Jogador 1: (['Valete', '2', '9', 'Dama', '5'], 'Ouros')
# Jogo do Jogador 1: Carta Alta
# Mão do Jogador 2: (['7', '3', 'Dama', '2', 'Rei'], 'Copas')
# Jogo do Jogador 2: Carta Alta
# Vencedor: Jogador 2
#
# Mão do Jogador 1: (['7', 'Dama', '8', 'Valete', '10'], 'Espadas')
# Jogo do Jogador 1: Carta Alta
# Mão do Jogador 2: (['Rei', '5', 'Dama', '8', '3'], 'Espadas')
# Jogo do Jogador 2: Carta Alta
# Vencedor: Jogador 2
#
# Mão do Jogador 1: (['6', '4', 'Ás', 'Valete', '9'], 'Copas')
# Jogo do Jogador 1: Carta Alta
# Mão do Jogador 2: (['Rei', '4', 'Dama', '9', 'Ás'], 'Ouros')
# Jogo do Jogador 2: Carta Alta
# Vencedor: Jogador 2
#
# Mão do Jogador 1: (['9', '2', '7', '10', '4'], 'Ouros')
# Jogo do Jogador 1: Carta Alta
# Mão do Jogador 2: (['10', 'Rei', '6', '9', 'Dama'], 'Ouros')
# Jogo do Jogador 2: Carta Alta
# Vencedor: Jogador 2
#
# Mão do Jogador 1: (['8', 'Valete', '7', '10', 'Rei'], 'Paus')
# Jogo do Jogador 1: Carta Alta
# Mão do Jogador 2: (['Valete', '3', '9', '8', '5'], 'Espadas')
# Jogo do Jogador 2: Carta Alta
# Vencedor: Jogador 1
#
# Mão do Jogador 1: (['Rei', '3', '4', '10', 'Dama'], 'Copas')
# Jogo do Jogador 1: Carta Alta
# Mão do Jogador 2: (['7', '4', '5', '9', 'Dama'], 'Espadas')
# Jogo do Jogador 2: Carta Alta
# Vencedor: Jogador 1
#
# Mão do Jogador 1: (['7', 'Valete', '6', '2', '5'], 'Ouros')
# Jogo do Jogador 1: Carta Alta
# Mão do Jogador 2: (['7', '10', 'Ás', '9', 'Dama'], 'Espadas')
# Jogo do Jogador 2: Carta Alta
# Vencedor: Jogador 2
#
# Mão do Jogador 1: (['9', 'Ás', '6', '2', 'Valete'], 'Ouros')
# Jogo do Jogador 1: Carta Alta
# Mão do Jogador 2: (['5', 'Ás', 'Rei', '9', 'Dama'], 'Espadas')
# Jogo do Jogador 2: Carta Alta
# Vencedor: Jogador 2
#
# Mão do Jogador 1: (['10', 'Rei', '2', '7', '4'], 'Espadas')
# Jogo do Jogador 1: Carta Alta
# Mão do Jogador 2: (['2', '5', 'Rei', '4', 'Valete'], 'Copas')
# Jogo do Jogador 2: Carta Alta
# Vencedor: Jogador 2
#
# Mão do Jogador 1: (['2', '6', 'Valete', 'Dama', '3'], 'Ouros')
# Jogo do Jogador 1: Carta Alta
# Mão do Jogador 2: (['8', '9', '4', '7', 'Ás'], 'Ouros')
# Jogo do Jogador 2: Carta Alta
# Vencedor: Jogador 2
#
# Mão do Jogador 1: (['Ás', '2', 'Dama', '3', '7'], 'Ouros')
# Jogo do Jogador 1: Carta Alta
# Mão do Jogador 2: (['9', '8', 'Ás', 'Dama', '3'], 'Copas')
# Jogo do Jogador 2: Carta Alta
# Vencedor: Jogador 2
#
# Mão do Jogador 1: (['Dama', '5', '2', 'Ás', '9'], 'Copas')
# Jogo do Jogador 1: Carta Alta
# Mão do Jogador 2: (['Ás', '4', '10', '3', '9'], 'Copas')
# Jogo do Jogador 2: Carta Alta
# Vencedor: Jogador 1
#
# Mão do Jogador 1: (['5', '2', 'Dama', '6', '9'], 'Paus')
# Jogo do Jogador 1: Carta Alta
# Mão do Jogador 2: (['Rei', '2', '8', '6', 'Valete'], 'Espadas')
# Jogo do Jogador 2: Carta Alta
# Vencedor: Jogador 2
#
# Mão do Jogador 1: (['3', 'Rei', '5', '9', '4'], 'Ouros')
# Jogo do Jogador 1: Carta Alta
# Mão do Jogador 2: (['Ás', '10', 'Dama', 'Valete', '9'], 'Paus')
# Jogo do Jogador 2: Carta Alta
# Vencedor: Jogador 2
#
# Mão do Jogador 1: (['5', 'Ás', '3', '6', '10'], 'Espadas')
# Jogo do Jogador 1: Carta Alta
# Mão do Jogador 2: (['7', '3', '8', '5', '10'], 'Paus')
# Jogo do Jogador 2: Carta Alta
# Vencedor: Jogador 1
#
# Mão do Jogador 1: (['2', '6', '7', '9', 'Dama'], 'Paus')
# Jogo do Jogador 1: Carta Alta
# Mão do Jogador 2: (['8', '7', '6', 'Rei', 'Dama'], 'Paus')
# Jogo do Jogador 2: Carta Alta
# Vencedor: Jogador 2
#
# Mão do Jogador 1: (['9', '6', 'Ás', 'Dama', '7'], 'Paus')
# Jogo do Jogador 1: Carta Alta
# Mão do Jogador 2: (['9', '2', 'Ás', '4', 'Dama'], 'Espadas')
# Jogo do Jogador 2: Carta Alta
# Vencedor: Jogador 1
#
# Mão do Jogador 1: (['9', '6', '7', 'Rei', '4'], 'Paus')
# Jogo do Jogador 1: Carta Alta
# Mão do Jogador 2: (['Valete', '3', '2', 'Ás', '5'], 'Ouros')
# Jogo do Jogador 2: Carta Alta
# Vencedor: Jogador 2
#
# Mão do Jogador 1: (['Dama', 'Valete', 'Rei', '9', '8'], 'Copas')
# Jogo do Jogador 1: Carta Alta
# Mão do Jogador 2: (['Ás', '7', '2', '5', '3'], 'Ouros')
# Jogo do Jogador 2: Carta Alta
# Vencedor: Jogador 2
#
# Mão do Jogador 1: (['Valete', '6', '5', 'Dama', 'Rei'], 'Paus')
# Jogo do Jogador 1: Carta Alta
# Mão do Jogador 2: (['3', '10', '9', '2', '8'], 'Copas')
# Jogo do Jogador 2: Carta Alta
# Vencedor: Jogador 1
#
# Mão do Jogador 1: (['9', '7', 'Dama', '4', '5'], 'Ouros')
# Jogo do Jogador 1: Carta Alta
# Mão do Jogador 2: (['6', '4', 'Valete', 'Ás', '5'], 'Espadas')
# Jogo do Jogador 2: Carta Alta
# Vencedor: Jogador 2
#
# Mão do Jogador 1: (['9', '6', '5', 'Dama', '3'], 'Paus')
# Jogo do Jogador 1: Carta Alta
# Mão do Jogador 2: (['Ás', '9', 'Dama', '3', 'Rei'], 'Paus')
# Jogo do Jogador 2: Carta Alta
# Vencedor: Jogador 2
#
# Mão do Jogador 1: (['8', '4', '7', '5', '9'], 'Paus')
# Jogo do Jogador 1: Carta Alta
# Mão do Jogador 2: (['6', '4', 'Rei', 'Valete', '3'], 'Ouros')
# Jogo do Jogador 2: Carta Alta
# Vencedor: Jogador 2
#
# Mão do Jogador 1: (['8', 'Ás', '3', '7', 'Valete'], 'Ouros')
# Jogo do Jogador 1: Carta Alta
# Mão do Jogador 2: (['Dama', 'Rei', '7', 'Valete', '2'], 'Copas')
# Jogo do Jogador 2: Carta Alta
# Vencedor: Jogador 1
#
# Mão do Jogador 1: (['Valete', '9', '4', '10', 'Dama'], 'Ouros')
# Jogo do Jogador 1: Carta Alta
# Mão do Jogador 2: (['3', 'Rei', '2', '6', '7'], 'Copas')
# Jogo do Jogador 2: Carta Alta
# Vencedor: Jogador 2
#
# Mão do Jogador 1: (['Valete', '9', '2', 'Ás', '3'], 'Copas')
# Jogo do Jogador 1: Carta Alta
# Mão do Jogador 2: (['Valete', '4', '9', '6', 'Dama'], 'Copas')
# Jogo do Jogador 2: Carta Alta
# Vencedor: Jogador 1
#
# Mão do Jogador 1: (['6', 'Valete', '5', '4', 'Ás'], 'Paus')
# Jogo do Jogador 1: Carta Alta
# Mão do Jogador 2: (['Valete', 'Dama', '10', '4', '3'], 'Paus')
# Jogo do Jogador 2: Carta Alta
# Vencedor: Jogador 1
#
# Mão do Jogador 1: (['10', 'Dama', '9', '3', '7'], 'Espadas')
# Jogo do Jogador 1: Carta Alta
# Mão do Jogador 2: (['Valete', '2', 'Ás', '8', '6'], 'Copas')
# Jogo do Jogador 2: Carta Alta
# Vencedor: Jogador 2
#
# Mão do Jogador 1: (['Ás', '7', '2', '4', '6'], 'Espadas')
# Jogo do Jogador 1: Carta Alta
# Mão do Jogador 2: (['9', '4', 'Ás', '10', 'Dama'], 'Paus')
# Jogo do Jogador 2: Carta Alta
# Vencedor: Jogador 2
#
# Mão do Jogador 1: (['9', '5', '2', '8', '7'], 'Espadas')
# Jogo do Jogador 1: Carta Alta
# Mão do Jogador 2: (['Ás', 'Valete', '9', '7', '8'], 'Espadas')
# Jogo do Jogador 2: Carta Alta
# Vencedor: Jogador 2
#
# Mão do Jogador 1: (['7', '9', '4', 'Ás', '5'], 'Copas')
# Jogo do Jogador 1: Carta Alta
# Mão do Jogador 2: (['10', '4', '6', 'Rei', 'Valete'], 'Copas')
# Jogo do Jogador 2: Carta Alta
# Vencedor: Jogador 1
#
# Mão do Jogador 1: (['6', 'Ás', '8', '2', '4'], 'Espadas')
# Jogo do Jogador 1: Carta Alta
# Mão do Jogador 2: (['7', 'Ás', '4', 'Dama', '2'], 'Paus')
# Jogo do Jogador 2: Carta Alta
# Vencedor: Jogador 2
#
# Mão do Jogador 1: (['4', '6', '8', '2', '10'], 'Espadas')
# Jogo do Jogador 1: Carta Alta
# Mão do Jogador 2: (['3', '10', '2', '4', 'Ás'], 'Espadas')
# Jogo do Jogador 2: Carta Alta
# Vencedor: Jogador 2
#
# Mão do Jogador 1: (['Ás', 'Rei', '2', 'Dama', '3'], 'Espadas')
# Jogo do Jogador 1: Carta Alta
# Mão do Jogador 2: (['Valete', 'Ás', 'Rei', '10', '9'], 'Paus')
# Jogo do Jogador 2: Carta Alta
# Vencedor: Jogador 1
#
# Mão do Jogador 1: (['Valete', '5', 'Dama', '3', '7'], 'Paus')
# Jogo do Jogador 1: Carta Alta
# Mão do Jogador 2: (['2', '7', '8', '6', '4'], 'Copas')
# Jogo do Jogador 2: Carta Alta
# Vencedor: Jogador 1
#
# Mão do Jogador 1: (['6', 'Rei', '9', '10', '4'], 'Espadas')
# Jogo do Jogador 1: Carta Alta
# Mão do Jogador 2: (['5', '9', '8', '2', '3'], 'Espadas')
# Jogo do Jogador 2: Carta Alta
# Vencedor: Jogador 1
#
# Mão do Jogador 1: (['10', '4', '2', '7', 'Valete'], 'Copas')
# Jogo do Jogador 1: Carta Alta
# Mão do Jogador 2: (['6', '3', 'Rei', '2', 'Ás'], 'Paus')
# Jogo do Jogador 2: Carta Alta
# Vencedor: Jogador 2
#
# Mão do Jogador 1: (['Ás', '3', '5', 'Valete', 'Rei'], 'Paus')
# Jogo do Jogador 1: Carta Alta
# Mão do Jogador 2: (['6', '4', '9', '10', '5'], 'Espadas')
# Jogo do Jogador 2: Carta Alta
# Vencedor: Jogador 1
#
# Mão do Jogador 1: (['Dama', '3', '2', 'Rei', '10'], 'Ouros')
# Jogo do Jogador 1: Carta Alta
# Mão do Jogador 2: (['5', '6', '3', '7', '8'], 'Copas')
# Jogo do Jogador 2: Carta Alta
# Vencedor: Jogador 1
#
# Mão do Jogador 1: (['7', '4', '2', 'Ás', '3'], 'Paus')
# Jogo do Jogador 1: Carta Alta
# Mão do Jogador 2: (['6', '10', '2', 'Dama', 'Rei'], 'Espadas')
# Jogo do Jogador 2: Carta Alta
# Vencedor: Jogador 1
#
# Mão do Jogador 1: (['8', '5', '6', '4', 'Rei'], 'Paus')
# Jogo do Jogador 1: Carta Alta
# Mão do Jogador 2: (['Ás', '9', 'Valete', '2', '4'], 'Ouros')
# Jogo do Jogador 2: Carta Alta
# Vencedor: Jogador 2
#
# Mão do Jogador 1: (['10', '8', '4', '7', '6'], 'Ouros')
# Jogo do Jogador 1: Carta Alta
# Mão do Jogador 2: (['7', '3', '10', 'Rei', 'Ás'], 'Paus')
# Jogo do Jogador 2: Carta Alta
# Vencedor: Jogador 2
#
# Mão do Jogador 1: (['6', '4', 'Valete', '5', '3'], 'Paus')
# Jogo do Jogador 1: Carta Alta
# Mão do Jogador 2: (['5', '4', '9', 'Ás', '8'], 'Espadas')
# Jogo do Jogador 2: Carta Alta
# Vencedor: Jogador 2
#
# Mão do Jogador 1: (['3', '8', '5', '4', '9'], 'Ouros')
# Jogo do Jogador 1: Carta Alta
# Mão do Jogador 2: (['5', 'Valete', 'Dama', '4', '7'], 'Paus')
# Jogo do Jogador 2: Carta Alta
# Vencedor: Jogador 2
#
# Mão do Jogador 1: (['6', '2', '7', 'Dama', '9'], 'Ouros')
# Jogo do Jogador 1: Carta Alta
# Mão do Jogador 2: (['6', '5', '9', '10', 'Valete'], 'Ouros')
# Jogo do Jogador 2: Carta Alta
# Vencedor: Jogador 1
#
# Mão do Jogador 1: (['8', '10', 'Rei', '3', '7'], 'Paus')
# Jogo do Jogador 1: Carta Alta
# Mão do Jogador 2: (['4', 'Dama', '7', 'Valete', '3'], 'Paus')
# Jogo do Jogador 2: Carta Alta
# Vencedor: Jogador 1
#
# Mão do Jogador 1: (['Dama', '9', '2', '3', '5'], 'Paus')
# Jogo do Jogador 1: Carta Alta
# Mão do Jogador 2: (['Dama', '5', 'Valete', 'Rei', '9'], 'Paus')
# Jogo do Jogador 2: Carta Alta
# Vencedor: Jogador 2
#
# Mão do Jogador 1: (['5', '8', '2', '4', '6'], 'Espadas')
# Jogo do Jogador 1: Carta Alta
# Mão do Jogador 2: (['8', '9', '3', '7', 'Ás'], 'Copas')
# Jogo do Jogador 2: Carta Alta
# Vencedor: Jogador 2
#
# Mão do Jogador 1: (['Ás', '4', '2', '6', '10'], 'Paus')
# Jogo do Jogador 1: Carta Alta
# Mão do Jogador 2: (['10', '6', 'Valete', '2', 'Rei'], 'Espadas')
# Jogo do Jogador 2: Carta Alta
# Vencedor: Jogador 1
#
# Mão do Jogador 1: (['Rei', '6', '5', '7', '9'], 'Ouros')
# Jogo do Jogador 1: Carta Alta
# Mão do Jogador 2: (['10', '9', 'Dama', '2', '3'], 'Espadas')
# Jogo do Jogador 2: Carta Alta
# Vencedor: Jogador 1
#
# Mão do Jogador 1: (['3', '4', '10', 'Rei', 'Ás'], 'Espadas')
# Jogo do Jogador 1: Carta Alta
# Mão do Jogador 2: (['2', '6', '10', 'Valete', 'Dama'], 'Copas')
# Jogo do Jogador 2: Carta Alta
# Vencedor: Jogador 1
#
# Mão do Jogador 1: (['Ás', '3', 'Dama', 'Rei', '5'], 'Copas')
# Jogo do Jogador 1: Carta Alta
# Mão do Jogador 2: (['Rei', 'Ás', '7', '6', '3'], 'Paus')
# Jogo do Jogador 2: Carta Alta
# Vencedor: Jogador 1
#
# Mão do Jogador 1: (['Ás', '7', '4', 'Rei', '3'], 'Paus')
# Jogo do Jogador 1: Carta Alta
# Mão do Jogador 2: (['Ás', '7', '3', '8', 'Rei'], 'Copas')
# Jogo do Jogador 2: Carta Alta
# Vencedor: Jogador 2
#
# Mão do Jogador 1: (['6', '10', 'Dama', '9', '5'], 'Paus')
# Jogo do Jogador 1: Carta Alta
# Mão do Jogador 2: (['5', '4', '6', '3', '2'], 'Copas')
# Jogo do Jogador 2: Sequência
# Vencedor: Jogador 2
#
# Mão do Jogador 1: (['9', '5', '10', '8', '3'], 'Paus')
# Jogo do Jogador 1: Carta Alta
# Mão do Jogador 2: (['7', '9', 'Rei', 'Valete', '5'], 'Ouros')
# Jogo do Jogador 2: Carta Alta
# Vencedor: Jogador 2
#
# Mão do Jogador 1: (['Ás', '8', 'Rei', 'Dama', 'Valete'], 'Copas')
# Jogo do Jogador 1: Carta Alta
# Mão do Jogador 2: (['9', '4', '8', '10', '6'], 'Paus')
# Jogo do Jogador 2: Carta Alta
# Vencedor: Jogador 1
#
# Mão do Jogador 1: (['6', '3', 'Valete', '7', '2'], 'Ouros')
# Jogo do Jogador 1: Carta Alta
# Mão do Jogador 2: (['9', '7', 'Valete', '2', '8'], 'Copas')
# Jogo do Jogador 2: Carta Alta
# Vencedor: Jogador 2
#
# Mão do Jogador 1: (['7', '8', 'Rei', '10', '6'], 'Paus')
# Jogo do Jogador 1: Carta Alta
# Mão do Jogador 2: (['Valete', '10', '2', 'Dama', '6'], 'Espadas')
# Jogo do Jogador 2: Carta Alta
# Vencedor: Jogador 1
#
# Mão do Jogador 1: (['Dama', '10', '3', '8', '6'], 'Ouros')
# Jogo do Jogador 1: Carta Alta
# Mão do Jogador 2: (['3', '8', 'Ás', 'Valete', '10'], 'Espadas')
# Jogo do Jogador 2: Carta Alta
# Vencedor: Jogador 2
#
# Mão do Jogador 1: (['8', '10', 'Valete', 'Ás', '3'], 'Paus')
# Jogo do Jogador 1: Carta Alta
# Mão do Jogador 2: (['4', 'Ás', '5', '6', 'Dama'], 'Copas')
# Jogo do Jogador 2: Carta Alta
# Vencedor: Jogador 2
#
# Mão do Jogador 1: (['4', '7', '3', '8', '5'], 'Paus')
# Jogo do Jogador 1: Carta Alta
# Mão do Jogador 2: (['10', '7', '6', 'Rei', '3'], 'Paus')
# Jogo do Jogador 2: Carta Alta
# Vencedor: Jogador 2
#
# Mão do Jogador 1: (['Dama', '10', 'Valete', '4', '7'], 'Ouros')
# Jogo do Jogador 1: Carta Alta
# Mão do Jogador 2: (['Dama', '4', '10', '2', 'Rei'], 'Paus')
# Jogo do Jogador 2: Carta Alta
# Vencedor: Jogador 2
#
# Mão do Jogador 1: (['4', 'Dama', '7', 'Rei', '9'], 'Ouros')
# Jogo do Jogador 1: Carta Alta
# Mão do Jogador 2: (['8', '2', 'Rei', '7', '6'], 'Paus')
# Jogo do Jogador 2: Carta Alta
# Vencedor: Jogador 1
#
# Mão do Jogador 1: (['2', '9', 'Ás', '6', '7'], 'Ouros')
# Jogo do Jogador 1: Carta Alta
# Mão do Jogador 2: (['Dama', '6', 'Ás', 'Valete', 'Rei'], 'Paus')
# Jogo do Jogador 2: Carta Alta
# Vencedor: Jogador 2
#
# Mão do Jogador 1: (['2', '10', '8', '5', 'Ás'], 'Espadas')
# Jogo do Jogador 1: Carta Alta
# Mão do Jogador 2: (['8', '10', 'Dama', '3', '5'], 'Ouros')
# Jogo do Jogador 2: Carta Alta
# Vencedor: Jogador 1
#
# Mão do Jogador 1: (['5', 'Ás', '2', 'Rei', 'Dama'], 'Espadas')
# Jogo do Jogador 1: Carta Alta
# Mão do Jogador 2: (['Valete', '4', '2', 'Dama', '6'], 'Ouros')
# Jogo do Jogador 2: Carta Alta
# Vencedor: Jogador 1
#
# Mão do Jogador 1: (['Valete', 'Dama', '7', '9', '8'], 'Espadas')
# Jogo do Jogador 1: Carta Alta
# Mão do Jogador 2: (['7', '8', '4', '6', '9'], 'Ouros')
# Jogo do Jogador 2: Carta Alta
# Vencedor: Jogador 1
#
# Mão do Jogador 1: (['2', '6', '9', 'Dama', 'Ás'], 'Ouros')
# Jogo do Jogador 1: Carta Alta
# Mão do Jogador 2: (['10', '7', '6', 'Rei', '5'], 'Espadas')
# Jogo do Jogador 2: Carta Alta
# Vencedor: Jogador 1
#
# Mão do Jogador 1: (['Ás', '4', '10', '5', 'Dama'], 'Ouros')
# Jogo do Jogador 1: Carta Alta
# Mão do Jogador 2: (['3', '8', '6', '5', '9'], 'Paus')
# Jogo do Jogador 2: Carta Alta
# Vencedor: Jogador 1
#
# Mão do Jogador 1: (['2', '4', '10', 'Ás', '6'], 'Paus')
# Jogo do Jogador 1: Carta Alta
# Mão do Jogador 2: (['Rei', '10', '5', '4', 'Ás'], 'Espadas')
# Jogo do Jogador 2: Carta Alta
# Vencedor: Jogador 2
#
# Mão do Jogador 1: (['Valete', '9', 'Ás', '3', '10'], 'Copas')
# Jogo do Jogador 1: Carta Alta
# Mão do Jogador 2: (['9', 'Dama', '6', '4', 'Rei'], 'Copas')
# Jogo do Jogador 2: Carta Alta
# Vencedor: Jogador 1
#
# Mão do Jogador 1: (['10', '7', 'Rei', 'Ás', '5'], 'Espadas')
# Jogo do Jogador 1: Carta Alta
# Mão do Jogador 2: (['Valete', '7', '5', '10', 'Ás'], 'Paus')
# Jogo do Jogador 2: Carta Alta
# Vencedor: Jogador 1
#
# Mão do Jogador 1: (['Dama', '10', '5', '3', '8'], 'Espadas')
# Jogo do Jogador 1: Carta Alta
# Mão do Jogador 2: (['Valete', '4', '9', '6', '7'], 'Copas')
# Jogo do Jogador 2: Carta Alta
# Vencedor: Jogador 1
#
# Mão do Jogador 1: (['7', 'Rei', '6', '5', 'Dama'], 'Copas')
# Jogo do Jogador 1: Carta Alta
# Mão do Jogador 2: (['9', 'Rei', '5', '4', '3'], 'Paus')
# Jogo do Jogador 2: Carta Alta
# Vencedor: Jogador 1
#
# Mão do Jogador 1: (['3', 'Rei', '8', '4', '9'], 'Copas')
# Jogo do Jogador 1: Carta Alta
# Mão do Jogador 2: (['Rei', '10', 'Ás', '5', '4'], 'Paus')
# Jogo do Jogador 2: Carta Alta
# Vencedor: Jogador 2
#
# Mão do Jogador 1: (['9', '10', '2', '8', 'Valete'], 'Ouros')
# Jogo do Jogador 1: Carta Alta
# Mão do Jogador 2: (['2', '7', 'Valete', 'Ás', '8'], 'Copas')
# Jogo do Jogador 2: Carta Alta
# Vencedor: Jogador 2
#
# Mão do Jogador 1: (['3', 'Valete', '6', '9', '2'], 'Paus')
# Jogo do Jogador 1: Carta Alta
# Mão do Jogador 2: (['6', '2', 'Valete', '7', 'Ás'], 'Ouros')
# Jogo do Jogador 2: Carta Alta
# Vencedor: Jogador 2
#
# Mão do Jogador 1: (['Rei', '8', '3', '6', '5'], 'Ouros')
# Jogo do Jogador 1: Carta Alta
# Mão do Jogador 2: (['6', '8', '3', 'Ás', '10'], 'Copas')
# Jogo do Jogador 2: Carta Alta
# Vencedor: Jogador 2
#
# Mão do Jogador 1: (['Rei', '4', 'Valete', '5', '10'], 'Paus')
# Jogo do Jogador 1: Carta Alta
# Mão do Jogador 2: (['9', '10', 'Rei', 'Ás', '3'], 'Paus')
# Jogo do Jogador 2: Carta Alta
# Vencedor: Jogador 2
#
# Mão do Jogador 1: (['9', '5', '6', '10', '2'], 'Copas')
# Jogo do Jogador 1: Carta Alta
# Mão do Jogador 2: (['Valete', '2', '10', '9', '4'], 'Copas')
# Jogo do Jogador 2: Carta Alta
# Vencedor: Jogador 2
#
# Mão do Jogador 1: (['6', 'Valete', 'Dama', 'Rei', '2'], 'Paus')
# Jogo do Jogador 1: Carta Alta
# Mão do Jogador 2: (['6', '2', 'Rei', '4', '10'], 'Espadas')
# Jogo do Jogador 2: Carta Alta
# Vencedor: Jogador 1
#
# Mão do Jogador 1: (['9', '6', '4', '2', '8'], 'Espadas')
# Jogo do Jogador 1: Carta Alta
# Mão do Jogador 2: (['10', '6', '9', 'Ás', 'Dama'], 'Espadas')
# Jogo do Jogador 2: Carta Alta
# Vencedor: Jogador 2
#
# Mão do Jogador 1: (['4', 'Ás', 'Rei', '9', '3'], 'Ouros')
# Jogo do Jogador 1: Carta Alta
# Mão do Jogador 2: (['2', '4', '10', 'Valete', 'Dama'], 'Ouros')
# Jogo do Jogador 2: Carta Alta
# Vencedor: Jogador 1
